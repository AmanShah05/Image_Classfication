# %%
# !pip install tensorflow opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp39-cp39-macosx_10_15_x86_64.whl (230.1 MB)
# Collecting opencv-python
#   Using cached opencv_python-4.7.0.72-cp37-abi3-macosx_10_16_x86_64.whl (53.9 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp39-cp39-macosx_10_12_x86_64.whl (7.4 MB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.22.1-cp37-abi3-macosx_10_9_universal2.whl (397 kB)
# Requirement already satisfied: libclang>=13.0.0 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.51.3-cp39-cp39-macosx_10_10_universal2.whl (8.2 MB)
# Requirement already satisfied: setuptools in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from tensorflow) (58.0.4)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting numpy<1.24,>=1.22
#   Using cached numpy-1.23.5-cp39-cp39-macosx_10_9_x86_64.whl (18.1 MB)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.6-py3-none-any.whl
# Collecting h5py>=2.9.0
#   Using cached h5py-3.8.0-cp39-cp39-macosx_10_9_x86_64.whl (3.2 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Collecting keras<2.13,>=2.12.0
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: packaging in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorflow) (1.14.1)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.8.2)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp39-cp39-macosx_10_9_x86_64.whl (244 kB)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.39.2-py3-none-any.whl (1.0 MB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.4.0-2-cp39-cp39-macosx_10_10_x86_64.whl (3.3 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Collecting scipy>=1.5
#   Using cached scipy-1.10.1-cp39-cp39-macosx_10_9_x86_64.whl (35.2 MB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.16.3-py2.py3-none-any.whl (177 kB)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.0-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.1.0-cp39-cp39-macosx_10_9_x86_64.whl (124 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/amanshah/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: tensorflow-estimator, tensorboard-data-server, rsa, pyparsing, pyasn1-modules, protobuf, pillow, oauthlib, numpy, kiwisolver, keras, importlib-resources, grpcio, google-pasta, gast, fonttools, cycler, charset-normalizer, certifi, cachetools, astunparse, absl-py, scipy, requests, opt-einsum, opencv-python, markdown, h5py, google-auth, contourpy, requests-oauthlib, matplotlib, jax, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed absl-py-1.4.0 astunparse-1.6.3 cachetools-5.3.0 certifi-2022.12.7 charset-normalizer-3.1.0 contourpy-1.0.7 cycler-0.11.0 fonttools-4.39.2 gast-0.4.0 google-auth-2.16.3 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.3 h5py-3.8.0 importlib-resources-5.12.0 jax-0.4.6 keras-2.12.0 kiwisolver-1.4.4 markdown-3.4.3 matplotlib-3.7.1 numpy-1.23.5 oauthlib-3.2.2 opencv-python-4.7.0.72 opt-einsum-3.3.0 pillow-9.4.0 protobuf-4.22.1 pyasn1-modules-0.2.8 pyparsing-3.0.9 requests-2.28.2 requests-oauthlib-1.3.1 rsa-4.9 scipy-1.10.1 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tensorflow-2.12.0 tensorflow-estimator-2.12.0

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ---------
# absl-py                      1.4.0
# altgraph                     0.17.2
# anyio                        3.6.2
# appnope                      0.1.3
# argon2-cffi                  21.3.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.2.1
# astunparse                   1.6.3
# attrs                        22.2.0
# backcall                     0.2.0
# beautifulsoup4               4.12.0
# bleach                       6.0.0
# cachetools                   5.3.0
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           3.1.0
# comm                         0.1.3
# contourpy                    1.0.7
# cycler                       0.11.0
# debugpy                      1.6.6
# decorator                    5.1.1
# defusedxml                   0.7.1
# executing                    1.2.0
# fastjsonschema               2.16.3
# flatbuffers                  23.3.3
# fonttools                    4.39.2
# fqdn                         1.5.1
# future                       0.18.2
# gast                         0.4.0
# google-auth                  2.16.3
# google-auth-oauthlib         0.4.6
# google-pasta                 0.2.0
# grpcio                       1.51.3
# h5py                         3.8.0
# idna                         3.4
# importlib-metadata           6.1.0
# importlib-resources          5.12.0
# ipykernel                    6.22.0
# ipython                      8.11.0
# ipython-genutils             0.2.0
# isoduration                  20.11.0
# jax                          0.4.6
# jedi                         0.18.2
# Jinja2                       3.1.2
# jsonpointer                  2.3
# jsonschema                   4.17.3
# jupyter_client               8.1.0
# jupyter_core                 5.3.0
# jupyter-events               0.6.3
# jupyter_server               2.5.0
# jupyter_server_terminals     0.4.4
# jupyterlab-pygments          0.2.2
# keras                        2.12.0
# kiwisolver                   1.4.4
# libclang                     16.0.0
# macholib                     1.15.2
# Markdown                     3.4.3
# MarkupSafe                   2.1.2
# matplotlib                   3.7.1
# matplotlib-inline            0.1.6
# mistune                      2.0.5
# nbclassic                    0.5.3
# nbclient                     0.7.2
# nbconvert                    7.2.10
# nbformat                     5.8.0
# nest-asyncio                 1.5.6
# notebook                     6.5.3
# notebook_shim                0.2.2
# numpy                        1.23.5
# oauthlib                     3.2.2
# opencv-python                4.7.0.72
# opt-einsum                   3.3.0
# packaging                    23.0
# pandocfilters                1.5.0
# parso                        0.8.3
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       9.4.0
# pip                          23.0.1
# platformdirs                 3.2.0
# prometheus-client            0.16.0
# prompt-toolkit               3.0.38
# protobuf                     4.22.1
# psutil                       5.9.4
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# pyasn1                       0.4.8
# pyasn1-modules               0.2.8
# pycparser                    2.21
# Pygments                     2.14.0
# pyparsing                    3.0.9
# pyrsistent                   0.19.3
# python-dateutil              2.8.2
# python-json-logger           2.0.7
# python-version               0.0.2
# PyYAML                       6.0
# pyzmq                        25.0.2
# requests                     2.28.2
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rsa                          4.9
# scipy                        1.10.1
# Send2Trash                   1.8.0
# setuptools                   58.0.4
# six                          1.15.0
# sniffio                      1.3.0
# soupsieve                    2.4
# stack-data                   0.6.2
# tensorboard                  2.12.0
# tensorboard-data-server      0.7.0
# tensorboard-plugin-wit       1.8.1
# tensorflow                   2.12.0
# tensorflow-estimator         2.12.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.2.0
# terminado                    0.17.1
# tinycss2                     1.2.1
# tornado                      6.2
# traitlets                    5.9.0
# typing_extensions            4.5.0
# uri-template                 1.2.0
# urllib3                      1.26.15
# wcwidth                      0.2.6
# webcolors                    1.12
# webencodings                 0.5.1
# websocket-client             1.5.1
# Werkzeug                     2.2.3
# wheel                        0.37.0
# wrapt                        1.14.1
# zipp                         3.15.0

# %%
import tensorflow as tf
import os
# Out:
# 2023-03-26 16:43:47.359636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
tf.config.list_physical_devices('CPU')
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
